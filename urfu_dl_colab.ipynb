# %% [markdown]
# <a href="https://colab.research.google.com/github/tiny-ri/learn_n_n/blob/main/urfu_dl_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Платформа Google Colab
#
# Google Colab - это бесплатная облачная платформа от Google для изучения машинного обучения.
#
# Colab позволяет создавать ноутбуки, которые содержат код на Python и описание этого кода. Сейчас вы видите как раз такой ноутбук.
#
# В ноутбуке можно запускать код и получать результаты его выполнения. Этот ноутбук вы можете только смотреть. Чтобы запустить код, создайте свою копию ноутбука "Файл" -> "Сохранить копию на Диске" (File -> Save a copy in Drive...)
#
# Для создания ноутбуков и запуска кода вам понадобится учетная запись Google.
#
# Учебный курс "[Программирование глубоких нейронных сетей на Python](https://openedu.ru/course/urfu/PYDNN/)".

# %% [markdown]
# ## Выполнение кода

# %%
# Это ячейка с кодом Python. Его можно запускать
a = 1
b = 2
c = a + b
print(c)
# Out:
# 3

# %% [markdown]
# Это ячейка с текстом. Чтобы изменить текст, щелкните на нем два раза мышью.
#
# Новый текст в ячейке

# %% [markdown]
# ## Библиотеки машинного обучения
#
# На платформе Google Colab установлено большое количество библиотек машинного обучения.
#
# Подключаем библиотеки `numpy` и `tensorflow`

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# Пример использования массивов `numpy`

# %%
a = np.array([0, 1, 2, 3])
b = np.array([4, 5, 6, 7])
c = a + b

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
c
# Out:
# array([ 4,  6,  8, 10])

# %% [markdown]
# Печатаем версию `tensorflow`

# %%
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ## Загрузка и сохранения файлов
#
# Код, который вы пишете в ноутбуке, выполняется на виртуальной машине в облаке Google. Если вы хотите обработать файлы (распознать картинку и т.п.), то вам нужно будет сначала загрузить эти файлы на диск виртуальной машины с локального компьютера.

# %%
from google.colab import files

# %% [markdown]
# **Загружаем файл с локального компьютера на диск виртуальной машины**

# %%
files.upload()
# Out:
#      <input type="file" id="files-749693cf-e469-4afe-bd67-166907ede777" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-749693cf-e469-4afe-bd67-166907ede777">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tshirt.jpg to tshirt.jpg
# ...

# %% [markdown]
# Посмотреть список файлов виртуальной машины можно на панели слева.
#
# Если вы знаете Linux, то можете использовать ее команды.

# %%
# !ls
# Out:
# sample_data  tshirt.jpg

# %% [markdown]
# Не пугайтесь, если не знаете Linux, курс можно освоить и без этого.
#
# **Сохраняем файл с диска виртуальной машины на локальный компьютер**
#
# Это пригодится, когда нужно будет сохранить обученную нейросеть для дальнейшего использования.

# %%
files.download('sample_data/california_housing_test.csv')

# %% [markdown]
# ## Графический ускоритель GPU
#
# Платформа Colab позволяет использовать GPU для ускорения обучения нейронной сети. Это бесплатно.
#
# GPU можно подключить в меню "Среда выполнения" -> "Сменить среду выполнения" -> "Аппаратный ускоритель" -> GPU (Runtime -> Change runtime type -> Hardware Accelerator -> GPU).
#
# После подключения GPU виртуальная машина перезапустится и все загруженные данные будут удалены. Поэтому рекомендуется подключать GPU в самом начале работы.
#
# На платформе Colaboratory доступны несколько моделей GPU: NVIDIA Tesla K80, T4, P4 и P100. Модели отличаются производительностью и объемом памяти. Выбрать модель нельзя.
#
# Узнать, какая модель подключена, можно следующей командой:

# %%
# !nvidia-smi
# Out:
# Tue Aug  4 16:48:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Краткие рекомендации
#
# 1. Для работы с Colab используйте учетную запись Google. Если у вас нет учетной записи, то создайте.
# 2. Для запуска кода в ноутбуке, создайте свою копию "Файл" -> "Сохранить копию на Диске" (File -> Save a copy in Drive...)
# 3. Не забудьте подключить GPU перед запуском кода. В противном случае нейросети будут обучаться очень медленно.
# 4. Ноутбуки - это обычные файлы в Google Drive. Ими можно делиться с другими людьми, в том числе участниками курса. Пункт меню "Поделиться" ("Share") в правом верхнем углу.
# 5. Пишите пояснения к своему коду в текстовых полях. Так вы сами через месяц не забудете, что именно делает код и почему.
# 6. Виртуальная машина в облаке Google работает 12 часов. После этого машину можно перезапустить и продолжить работу. Но все данные будут удалены.
